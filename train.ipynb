# %%
import argparse
import gym
import torch
import numpy as np
import time
import os
import datetime
import random
from tqdm import tqdm
from utils import Path, plot_results
from ppo import PPOAgent
from train import train_ppo_agent
import matplotlib.pyplot as plt
import test

# %% [markdown]
# We will try to train the half-cheetah enviroment utilizing the PPO algorithm developed in this library. We will test what different hyperparaters such as learning rate of critc and actor (we will keep them the same), policy updates per trajectory, reward clip ratio, and investigate the reward function over a 10,000 epochs (something that won't take a while without GPU support). We will conduct 12 different experiement with varying learning rate between [0.00001, 0.0001], policy updates between [5, 10, 64], and reward clip ratio between [0.1, 0.2].

# %% [markdown]
# Test1:
#     * Learning Rate: 0.00001
#     * Policy Updates: 5
#     * Reward Clip Ratio: 0.1
#
# Test2:
#     * Learning Rate: 0.0001
#     * Policy Updates: 5
#     * Reward Clip Ratio: 0.1
#
# Test3:
#     * Learning Rate: 0.00001
#     * Policy Updates: 10
#     * Reward Clip Ratio: 0.1
#
# Test4:
#     * Learning Rate: 0.0001
#     * Policy Updates: 10
#     * Reward Clip Ratio: 0.1
#
# Test5:
#     * Learning Rate: 0.00001
#     * Policy Updates: 64
#     * Reward Clip Ratio: 0.1
#
# Test6:
#     * Learning Rate: 0.0001
#     * Policy Updates: 64
#     * Reward Clip Ratio: 0.1
#
# Test7:
#     * Learning Rate: 0.00001
#     * Policy Updates: 5
#     * Reward Clip Ratio: 0.2
#
# Test8:
#     * Learning Rate: 0.0001
#     * Policy Updates: 5
#     * Reward Clip Ratio: 0.2
#
# Test9:
#     * Learning Rate: 0.00001
#     * Policy Updates: 10
#     * Reward Clip Ratio: 0.2
#
# Test10:
#     * Learning Rate: 0.0001
#     * Policy Updates: 10
#     * Reward Clip Ratio: 0.2
#
# Test11:
#     * Learning Rate: 0.00001
#     * Policy Updates: 64
#     * Reward Clip Ratio: 0.2
#
# Test12:
#     * Learning Rate: 0.0001
#     * Policy Updates: 64
#     * Reward Clip Ratio: 0.2

# %%
test1_hyperparameters = {"env": 'HalfCheetahMuJoCoEnv-v0', "activation": "ReLU", "layers": [256, 256], "epochs": 10000,  
                    "steps": 2048, "gamma": 0.99, "batch": 64, "eval_steps": 5000, "test_every_epoch": 1, "eval_epoch": 10,
                    "render": False, "save_dir": "./models/", "entropy": 0.01, "policy_updates": 5, "actor_lr": 0.00001,
                    "critic_lr": 0.00001, "esp_clip": 0.1, "grad_clip": 0.5, "plot_results_itr": 2500}

training_rewards1, testing_rewards1, mean_100_rewards1, actor_loss1, critic_loss1, epochs1 = train_ppo_agent(test1_hyperparameters)
# Out:
# WalkerBase::__init__
# argv[0]=
# argv[0]=

# %%
print(epochs)
plt.title('Training Reward vs Epochs Test1')
plt.ylabel('Rewards')
plt.xlabel('Epochs')
plt.plot(epochs1,training_rewards1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 print(epochs)
#       2 plt.title('Training Reward vs Epochs Test1')
#       3 plt.ylabel('Rewards')
#
# NameError: name 'epochs' is not defined

# %%
plt.title('Testing Reward vs Epochs Test 1')
plt.ylabel('Rewards')
plt.xlabel('Epochs')
plt.plot(epochs1,testing_rewards1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 4
#       2 plt.ylabel('Rewards')
#       3 plt.xlabel('Epochs')
# ----> 4 plt.plot(epochs1,testing_rewards1)
#
# NameError: name 'epochs1' is not defined

# %%
plt.title('Actor Loss vs Epochs Test 1')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.plot(epochs1,actor_loss1)

# %%
plt.title('Critic Loss vs Epochs Test 1')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.plot(epochs1,critic_loss1)

# %%
test2_hyperparameters = {"env": 'HalfCheetahMuJoCoEnv-v0', "activation": "ReLU", "layers": [256, 256], "epochs": 10000,  
                    "steps": 2048, "gamma": 0.99, "batch": 64, "eval_steps": 5000, "test_every_epoch": 10, "eval_epoch": 10,
                    "render": False, "save_dir": "./models/", "entropy": 0.01, "policy_updates": 5, "actor_lr": 0.0001,
                    "critic_lr": 0.0001, "esp_clip": 0.1, "grad_clip": 0.5, "plot_results_itr": 2500}
training_rewards2, testing_rewards2, mean_100_rewards2, actor_loss2, critic_loss2, epochs2 = train_ppo_agent(test2_hyperparameters)
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/cenv/lib/python3.9/site-packages/gym/spaces/box.py:84: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# WalkerBase::__init__
# argv[0]=
# argv[0]=
# MODEL HAS BEEN SAVE
# total train time -> 6034.99343419075
# combined actor-critic model weights path: ./models/'/half_cheetah_weights_skoutaa_221209_100846.pt

# %%
plt.title('Training Reward vs Epochs Test 2')
plt.ylabel('Rewards')
plt.xlabel('Epochs')
plt.plot(epochs2,training_rewards2)

# %%
plt.title('Testing Reward vs Epochs Test 2')
plt.ylabel('Rewards')
plt.xlabel('Epochs')
plt.plot(epochs2, testing_rewards2)

# %%
print(len(testing_rewards2))
# Out:
# 1000

# %%
epochs2 = [i for i in range(0, 10000)]
plt.title('Actor Loss vs Epochs Test 2')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.plot(epochs2, actor_loss2)

# %%
epochs2 = [i for i in range(0, 10000)]
plt.title('Critic Loss vs Epochs Test 2')
plt.ylabel('Loss')
plt.xlabel('Epochs')
print(len(epochs2))
plt.plot(epochs2, critic_loss2)
# Out:
# 10000

# %%
test3_hyperparameters = {"env": 'HalfCheetahMuJoCoEnv-v0', "activation": "ReLU", "layers": [256, 256], "epochs": 10000,  
                    "steps": 2048, "gamma": 0.99, "batch": 64, "eval_steps": 5000, "test_every_epoch": 10, "eval_epoch": 10,
                    "render": False, "save_dir": "./models/", "entropy": 0.01, "policy_updates": 10, "actor_lr": 0.00001,
                    "critic_lr": 0.00001, "esp_clip": 0.1, "grad_clip": 0.5, "plot_results_itr": 2500}
training_rewards3, testing_rewards3, mean_100_rewards3, actor_loss3, critic_loss3, epochs3 = train_ppo_agent(test3_hyperparameters)
# Out:
# WalkerBase::__init__
# argv[0]=
# argv[0]=
# MODEL HAS BEEN SAVE
# total train time -> 7537.150183200836
# combined actor-critic model weights path: ./models/'/half_cheetah_weights_skoutaa_221209_121423.pt

# %%
plt.title('Training Reward vs Epochs Test 3')
plt.ylabel('Rewards')
plt.xlabel('Epochs')
plt.plot(epochs3,training_rewards3)

# %%
epochs3 = [i * 10 for i in range(0, 1000)]
plt.title('Testing Reward vs Epochs Test 3')
plt.ylabel('Rewards')
plt.xlabel('Epochs')
plt.plot(epochs3, testing_rewards3)

# %% [markdown]
# Seems like a good run with around 1500+ rewrad compared to other experiements

# %%
plt.title('Actor Loss vs Epochs Test 3')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.plot(epochs3, actor_loss3)

# %%
plt.title('Critic Loss vs Epochs Test 3')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.plot(epochs3, critic_loss3)

# %%
test4_hyperparameters = {"env": 'HalfCheetahMuJoCoEnv-v0', "activation": "ReLU", "layers": [256, 256], "epochs": 10000,  
                    "steps": 2048, "gamma": 0.99, "batch": 64, "eval_steps": 5000, "test_every_epoch": 10, "eval_epoch": 10,
                    "render": False, "save_dir": "./models/", "entropy": 0.01, "policy_updates": 10, "actor_lr": 0.0001,
                    "critic_lr": 0.0001, "esp_clip": 0.1, "grad_clip": 0.5, "plot_results_itr": 2500}
training_rewards4, testing_rewards4, mean_100_rewards4, actor_loss4, critic_loss4, epochs4 = train_ppo_agent(test4_hyperparameters)
# Out:
# WalkerBase::__init__
# argv[0]=
# argv[0]=
# MODEL HAS BEEN SAVE
# total train time -> 8159.629549026489
# combined actor-critic model weights path: ./models/'/half_cheetah_weights_skoutaa_221209_143038.pt

# %%
plt.title('Training Reward vs Epochs Test 4')
plt.ylabel('Rewards')
plt.xlabel('Epochs')
plt.plot(epochs4,training_rewards4)

# %%
epochs4 = [i * 10 for i in range(0, 1000)]
plt.title('Testing Reward vs Epochs Test 4')
plt.ylabel('Rewards')
plt.xlabel('Epochs')
plt.plot(epochs4, testing_rewards4)

# %%
epochs4 = [i for i in range(0, 10000)]
plt.title('Actor Loss vs Epochs Test 4')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.plot(epochs4, actor_loss4)

# %%
epochs4 = [i for i in range(0, 10000)]
plt.title('Critic Loss vs Epochs Test 4')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.plot(epochs4, critic_loss4)

# %%
test5_hyperparameters = {"env": 'HalfCheetahMuJoCoEnv-v0', "activation": "ReLU", "layers": [256, 256], "epochs": 10000,  
                    "steps": 2048, "gamma": 0.99, "batch": 64, "eval_steps": 5000, "test_every_epoch": 10, "eval_epoch": 10,
                    "render": False, "save_dir": "./models/", "entropy": 0.01, "policy_updates": 64, "actor_lr": 0.00001,
                    "critic_lr": 0.00001, "esp_clip": 0.1, "grad_clip": 0.5, "plot_results_itr": 2500}
training_rewards5, testing_rewards5, mean_100_rewards5, actor_loss5, critic_loss5, epochs5 = train_ppo_agent(test5_hyperparameters)
# Out:
# WalkerBase::__init__
# argv[0]=
# argv[0]=
# MODEL HAS BEEN SAVE
# total train time -> 23659.577733278275
# combined actor-critic model weights path: ./models/'/half_cheetah_weights_skoutaa_221209_210459.pt

# %%
plt.title('Training Reward vs Epochs Test 5')
plt.ylabel('Rewards')
plt.xlabel('Epochs')
plt.plot(epochs5,training_rewards5)

# %%
epochs5 = [i * 10 for i in range(0, 1000)]
plt.title('Testing Reward vs Epochs Test 5')
plt.ylabel('Rewards')
plt.xlabel('Epochs')
plt.plot(epochs5, testing_rewards5)

# %%
epochs5 = [i for i in range(0, 10000)]
plt.title('Actor Loss vs Epochs Test 5')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.plot(epochs5, actor_loss5)

# %%
epochs5 = [i for i in range(0, 10000)]
plt.title('Critic Loss vs Epochs Test 5')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.plot(epochs5, critic_loss5)

# %%
test6_hyperparameters = {"env": 'HalfCheetahMuJoCoEnv-v0', "activation": "ReLU", "layers": [256, 256], "epochs": 10000,  
                    "steps": 2048, "gamma": 0.99, "batch": 64, "eval_steps": 5000, "test_every_epoch": 10, "eval_epoch": 10,
                    "render": False, "save_dir": "./models/", "entropy": 0.01, "policy_updates": 64, "actor_lr": 0.0001,
                    "critic_lr": 0.0001, "esp_clip": 0.1, "grad_clip": 0.5, "plot_results_itr": 2500}
training_rewards6, testing_rewards6, mean_100_rewards6, actor_loss6, critic_loss6, epochs6 = train_ppo_agent(test4_hyperparameters)
# Out:
# WalkerBase::__init__
# argv[0]=
# argv[0]=
# MODEL HAS BEEN SAVE
# total train time -> 8565.30500626564
# combined actor-critic model weights path: ./models/'/half_cheetah_weights_skoutaa_221209_232905.pt

# %%
plt.title('Training Reward vs Epochs Test 6')
plt.ylabel('Rewards')
plt.xlabel('Epochs')
plt.plot(epochs6,training_rewards6)

# %%
epochs6 = [i * 10 for i in range(0, 1000)]
plt.title('Testing Reward vs Epochs Test 5')
plt.ylabel('Rewards')
plt.xlabel('Epochs')
plt.plot(epochs6, testing_rewards6)

# %%
epochs6 = [i for i in range(0, 10000)]
plt.title('Actor Loss vs Epochs Test 6')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.plot(epochs6, actor_loss6)

# %%
epochs6 = [i for i in range(0, 10000)]
plt.title('Critic Loss vs Epochs Test 6')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.plot(epochs6, critic_loss6)

# %%
test7_hyperparameters = {"env": 'HalfCheetahMuJoCoEnv-v0', "activation": "ReLU", "layers": [256, 256], "epochs": 10000,  
                    "steps": 2048, "gamma": 0.99, "batch": 64, "eval_steps": 5000, "test_every_epoch": 10, "eval_epoch": 10,
                    "render": False, "save_dir": "./models/", "entropy": 0.01, "policy_updates": 5, "actor_lr": 0.00001,
                    "critic_lr": 0.00001, "esp_clip": 0.2, "grad_clip": 0.5, "plot_results_itr": 2500}
training_rewards7, testing_rewards7, mean_100_rewards7, actor_loss7, critic_loss7, epochs7 = train_ppo_agent(test4_hyperparameters)
# Out:
# WalkerBase::__init__
# argv[0]=
# argv[0]=
# MODEL HAS BEEN SAVE
# total train time -> 8073.518099784851
# combined actor-critic model weights path: ./models/'/half_cheetah_weights_skoutaa_221210_014519.pt

# %%
plt.title('Training Reward vs Epochs Test 7')
plt.ylabel('Rewards')
plt.xlabel('Epochs')
plt.plot(epochs7, training_rewards7)

# %%
epochs7 = [i * 10 for i in range(0, 1000)]
plt.title('Testing Reward vs Epochs Test 7')
plt.ylabel('Rewards')
plt.xlabel('Epochs')
plt.plot(epochs7, testing_rewards7)

# %%
epochs7 = [i for i in range(0, 10000)]
plt.title('Actor Loss vs Epochs Test 7')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.plot(epochs7, actor_loss7)

# %%
plt.title('Critic Loss vs Epochs Test 7')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.plot(epochs7, critic_loss7)

# %%
test8_hyperparameters = {"env": 'HalfCheetahMuJoCoEnv-v0', "activation": "ReLU", "layers": [256, 256], "epochs": 10000,  
                    "steps": 2048, "gamma": 0.99, "batch": 64, "eval_steps": 5000, "test_every_epoch": 10, "eval_epoch": 10,
                    "render": False, "save_dir": "./models/", "entropy": 0.01, "policy_updates": 5, "actor_lr": 0.0001,
                    "critic_lr": 0.0001, "esp_clip": 0.2, "grad_clip": 0.5, "plot_results_itr": 2500}
training_rewards8, testing_rewards8, mean_100_rewards8, actor_loss8, critic_loss8, epochs8 = train_ppo_agent(test8_hyperparameters)
# Out:
# WalkerBase::__init__
# argv[0]=
# argv[0]=
# MODEL HAS BEEN SAVE
# total train time -> 6100.476202964783
# combined actor-critic model weights path: ./models/half_cheetah_weights_skoutaa_221210_033003.pt

# %%
plt.title('Training Reward vs Epochs Test 8')
plt.ylabel('Rewards')
plt.xlabel('Epochs')
plt.plot(epochs8, training_rewards8)

# %%
epochs8 = [i * 10 for i in range(0, 1000)]
plt.title('Testing Reward vs Epochs Test 8')
plt.ylabel('Rewards')
plt.xlabel('Epochs')
plt.plot(epochs8, testing_rewards8)

# %%
epochs8 = [i for i in range(0, 10000)]
plt.title('Actor Loss vs Epochs Test 8')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.plot(epochs8, actor_loss8)

# %%
plt.title('Critic Loss vs Epochs Test 8')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.plot(epochs8, critic_loss8)

# %%
test9_hyperparameters = {"env": 'HalfCheetahMuJoCoEnv-v0', "activation": "ReLU", "layers": [256, 256], "epochs": 10000,  
                    "steps": 2048, "gamma": 0.99, "batch": 64, "eval_steps": 5000, "test_every_epoch": 10, "eval_epoch": 10,
                    "render": False, "save_dir": "./models/", "entropy": 0.01, "policy_updates": 10, "actor_lr": 0.00001,
                    "critic_lr": 0.00001, "esp_clip": 0.2, "grad_clip": 0.5, "plot_results_itr": 2500}
training_rewards9, testing_rewards9, mean_100_rewards9, actor_loss9, critic_loss9, epochs9 = train_ppo_agent(test9_hyperparameters)
# Out:
# WalkerBase::__init__
# argv[0]=
# argv[0]=
# MODEL HAS BEEN SAVE
# total train time -> 7402.966846942902
# combined actor-critic model weights path: ./models/half_cheetah_weights_skoutaa_221210_053641.pt

# %%
plt.title('Training Reward vs Epochs Test 9')
plt.ylabel('Rewards')
plt.xlabel('Epochs')
plt.plot(epochs9, training_rewards9)

# %%
epochs9 = [i * 10 for i in range(0, 1000)]
plt.title('Testing Reward vs Epochs Test 9')
plt.ylabel('Rewards')
plt.xlabel('Epochs')
plt.plot(epochs9, testing_rewards9)

# %%
epochs9 = [i  for i in range(0, 10000)]
plt.title('Actor Loss vs Epochs Test 9')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.plot(epochs9, actor_loss9)

# %%
epochs9 = [i  for i in range(0, 10000)]
plt.title('Critic Loss vs Epochs Test 9')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.plot(epochs9, critic_loss9)

# %%
test10_hyperparameters = {"env": 'HalfCheetahMuJoCoEnv-v0', "activation": "ReLU", "layers": [256, 256], "epochs": 10000,  
                    "steps": 2048, "gamma": 0.99, "batch": 64, "eval_steps": 5000, "test_every_epoch": 10, "eval_epoch": 10,
                    "render": False, "save_dir": "./models/", "entropy": 0.01, "policy_updates": 10, "actor_lr": 0.0001,
                    "critic_lr": 0.0001, "esp_clip": 0.2, "grad_clip": 0.5, "plot_results_itr": 2500}
training_rewards10, testing_rewards10, mean_100_rewards10, actor_loss10, critic_loss10, epochs10 = train_ppo_agent(test10_hyperparameters)
# Out:
# WalkerBase::__init__
# argv[0]=
# argv[0]=
# MODEL HAS BEEN SAVE
# total train time -> 8053.801937818527
# combined actor-critic model weights path: ./models/half_cheetah_weights_skoutaa_221210_075338.pt

# %%
epochs10 = [i  for i in range(0, 10000)]
plt.title('Training Reward vs Epochs Test 10')
plt.ylabel('Rewards')
plt.xlabel('Epochs')
plt.plot(epochs10, training_rewards10)

# %%
epochs10 = [i * 10  for i in range(0, 1000)]
plt.title('Testing Reward vs Epochs Test 10')
plt.ylabel('Rewards')
plt.xlabel('Epochs')
plt.plot(epochs10, testing_rewards10)

# %%
epochs10 = [i  for i in range(0, 10000)]
plt.title('Actor Loss vs Epochs Test 10')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.plot(epochs10, actor_loss10)

# %%
plt.title('Critic Loss vs Epochs Test 10')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.plot(epochs10, critic_loss10)

# %%
test11_hyperparameters = {"env": 'HalfCheetahMuJoCoEnv-v0', "activation": "ReLU", "layers": [256, 256], "epochs": 10000,  
                    "steps": 2048, "gamma": 0.99, "batch": 64, "eval_steps": 5000, "test_every_epoch": 10, "eval_epoch": 10,
                    "render": False, "save_dir": "./models/", "entropy": 0.01, "policy_updates": 64, "actor_lr": 0.00001,
                    "critic_lr": 0.00001, "esp_clip": 0.2, "grad_clip": 0.5, "plot_results_itr": 2500}
training_rewards11, testing_rewards11, mean_100_rewards11, actor_loss11, critic_loss11, epochs11 = train_ppo_agent(test11_hyperparameters)
# Out:
# WalkerBase::__init__
# argv[0]=
# argv[0]=
# MODEL HAS BEEN SAVE
# total train time -> 25691.692979335785
# combined actor-critic model weights path: ./models/half_cheetah_weights_skoutaa_221210_150405.pt

# %%
plt.title('Training Reward vs Epochs Test 11')
plt.ylabel('Rewards')
plt.xlabel('Epochs')
plt.plot(epochs11, training_rewards11)

# %%
epochs11 = [i * 10  for i in range(0, 1000)]
plt.title('Testing Reward vs Epochs Test 11')
plt.ylabel('Rewards')
plt.xlabel('Epochs')
plt.plot(epochs11, testing_rewards11)

# %%
epochs11 = [i for i in range(0, 10000)]
plt.title('Actor Loss vs Epochs Test 11')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.plot(epochs11, actor_loss11)

# %%
plt.title('Critic Loss vs Epochs Test 11')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.plot(epochs11, critic_loss11)

# %%
test12_hyperparameters = {"env": 'HalfCheetahMuJoCoEnv-v0', "activation": "ReLU", "layers": [256, 256], "epochs": 10000,  
                    "steps": 2048, "gamma": 0.99, "batch": 64, "eval_steps": 5000, "test_every_epoch": 10, "eval_epoch": 10,
                    "render": False, "save_dir": "./models/", "entropy": 0.01, "policy_updates": 64, "actor_lr": 0.0001,
                    "critic_lr": 0.0001, "esp_clip": 0.2, "grad_clip": 0.5, "plot_results_itr": 2500}
training_rewards12, testing_rewards12, mean_100_rewards12, actor_loss12, critic_loss12, epochs12 = train_ppo_agent(test12_hyperparameters)
# Out:
# WalkerBase::__init__
# argv[0]=
# argv[0]=
# MODEL HAS BEEN SAVE
# total train time -> 28219.258891820908
# combined actor-critic model weights path: ./models/half_cheetah_weights_skoutaa_221210_225514.pt

# %%
plt.title('Training Reward vs Epochs Test 12')
plt.ylabel('Rewards')
plt.xlabel('Epochs')
plt.plot(epochs12, training_rewards12)

# %%
epochs12 = [i * 10 for i in range(0, 1000)]
plt.title('Testing Reward vs Epochs Test 12')
plt.ylabel('Rewards')
plt.xlabel('Epochs')
plt.plot(epochs12, testing_rewards12)

# %%
epochs12 = [i  for i in range(0, 10000)]
plt.title('Actor Loss vs Epochs Test 12')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.plot(epochs12, actor_loss12)

# %%
epochs12 = [i  for i in range(0, 10000)]
plt.title('Critic Loss vs Epochs Test 12')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.plot(epochs12, critic_loss12)

# %% [markdown]
# We see that test 2 and 3 performed the best with the hyperparameterss learning rate equal to either 0.00001, or 0.0001, clipping ratio of 0.1 and policy updates of 5 each trajectory  iteration. Both test achieved a testing reward mean of aroud 1600 and a training reward mean of 1500. This is below state-of-the-arts PPO implementation that have training curves 4000-5000 mean training reward; however, this algorithm is able to make the agent properly work and tranverse its enviroment.

# %% [markdown]
# Below is the example code that runs the agent in the enviorment pybullet. I requires the user to install the pybullet-gym dependicies, gym, torch, etc (read the README.m file). A video (Half_Cheetah_PPO.mp4) has also been to this project to view how the agent performs in the testing enviroment.

# %%
args = {"env": 'HalfCheetahMuJoCoEnv-v0', "activation": "ReLU", "layers": [256, 256], "epochs": 10000,  
                    "steps": 2048, "gamma": 0.99, "batch": 64, "eval_steps": 5000, "test_every_epoch": 10, "eval_epoch": 10,
                    "render": False, "save_dir": "./models/'", "entropy": 0.01, "policy_updates": 64, "actor_lr": 0.0001,
                    "critic_lr": 0.0001, "esp_clip": 0.2, "grad_clip": 0.5, "plot_results_itr": 2500, "path": "./models/half_cheetah_weights_skoutaa_221209_121423.pt"}

test.test(args)
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/cenv/lib/python3.9/site-packages/gym/spaces/box.py:84: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# WalkerBase::__init__
# argv[0]=
# Version = 4.1 Metal - 76.3
# Vendor = Apple
# Renderer = Apple M1 Pro
# b3Printf: Selected demo: Physics Server
# startThreads creating 1 threads.
# starting thread 0
# started thread 0
# MotionThreadFunc thread started
# test epoch reward: 1713.3376759334176
# test epoch reward: 1669.5214185656084
# test epoch reward: 848.8782131410518
# test epoch reward: 1729.0429171049254
# test epoch reward: 1742.982481397936
# test epoch reward: 1720.9238558228622
# test epoch reward: 1736.6344292419378
# test epoch reward: -722.3048007632517
# test epoch reward: 1721.0160578690943
# test epoch reward: 1717.9992233516457
